# %%
# 드라이브와 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
menu_data = pd.read_csv('/content/drive/MyDrive/데이터분석 스터디/data/menu_data.csv')
menu_data.head()
# Out:
#            0         1      2         3       4        5     6    7    8
# 0     모닝롤/찐빵  우유/두유/주스  계란후라이    호두죽/쌀밥    된장찌개    쥐어채무침  포기김치  NaN  NaN
# 1  모닝롤/단호박샌드  우유/두유/주스  계란후라이     팥죽/쌀밥  호박젓국찌개    시래기조림  포기김치  NaN  NaN
# 2    모닝롤/베이글  우유/두유/주스  계란후라이  표고버섯죽/쌀밥    콩나물국  느타리호박볶음  포기김치  NaN  NaN
# 3  모닝롤/토마토샌드  우유/두유/주스  계란후라이     닭죽/쌀밥     근대국     멸치볶음  포기김치  NaN  NaN
# 4     모닝롤/와플  우유/두유/주스  계란후라이   쇠고기죽/쌀밥     재첩국     방풍나물  포기김치  NaN  NaN

# %%
# 열 처리
columns = ['A','B','C','D','E','F','G','H','I']
menu_data.columns = columns
menu_data.head(1)
# Out:
#         A         B      C       D     E      F     G    H    I
# 0  모닝롤/찐빵  우유/두유/주스  계란후라이  호두죽/쌀밥  된장찌개  쥐어채무침  포기김치  NaN  NaN

# %% [markdown]
# ## 분류 함수 정의

# %%
def categorize(data, category_list, convert_word):
    test = '|'.join(category_list)
    result = data.str.contains(test, na = False) # 포함되면 True, 아니면 False를 반환
    data[result] = convert_word

# %%
# 빵
bread_list = ['롤', '토스트', '빵', '샌드','카스테라','베이글', '팬케익', '컵케익','아이스슈','조각케익','슈크림','크리스마스케익', '딸기와플', '바게뜨', '수제마늘바게트', '버거']
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], bread_list, '빵')
menu_data.head(3)
# Out:
#    A         B      C         D       E        F     G    H    I
# 0  빵  우유/두유/주스  계란후라이    호두죽/쌀밥    된장찌개    쥐어채무침  포기김치  NaN  NaN
# 1  빵  우유/두유/주스  계란후라이     팥죽/쌀밥  호박젓국찌개    시래기조림  포기김치  NaN  NaN
# 2  빵  우유/두유/주스  계란후라이  표고버섯죽/쌀밥    콩나물국  느타리호박볶음  포기김치  NaN  NaN

# %%
# 돼지고기
pork_list = ['돈까스', '돈가스', '돈육', '제육', '탕수육', '돼지', '돈간장불고기', 
             '삼겹', '목살', '동파육', '깐풍육', '돼지고기', '오향장육', '카츠', 
             '돈갈비', '폭립', '두루치기', '돈사태', '수육', '보쌈', '꿔바로우', 
             '등갈비', '미트볼', '베이컨', '족발', '등뼈', '어떡햄', '소세지', 
             '소시지', '비엔나', '햄', '고기완자전']
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], pork_list , '돼지고기')
menu_data.head(3)
# Out:
#    A         B      C         D       E        F     G    H    I
# 0  빵  우유/두유/주스  계란후라이    호두죽/쌀밥    된장찌개    쥐어채무침  포기김치  NaN  NaN
# 1  빵  우유/두유/주스  계란후라이     팥죽/쌀밥  호박젓국찌개    시래기조림  포기김치  NaN  NaN
# 2  빵  우유/두유/주스  계란후라이  표고버섯죽/쌀밥    콩나물국  느타리호박볶음  포기김치  NaN  NaN

# %%
# 찌개 / 국
soup_list = ['찌개','국','탕','육개장','스프','미소시루','샤브샤브','지리','누룽지','찌깨','닭개장', '수제비', '개장']
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], soup_list , '국')
menu_data.head(3)
# Out:
#    A         B      C         D  E        F     G    H    I
# 0  빵  우유/두유/주스  계란후라이    호두죽/쌀밥  국    쥐어채무침  포기김치  NaN  NaN
# 1  빵  우유/두유/주스  계란후라이     팥죽/쌀밥  국    시래기조림  포기김치  NaN  NaN
# 2  빵  우유/두유/주스  계란후라이  표고버섯죽/쌀밥  국  느타리호박볶음  포기김치  NaN  NaN

# %%
# 김치
gimchi_list =['포기김치','깍두기','알타리김치','열무김치','나박물김치','피클','단무지','겉절이','백김치','배추김치','파김치','갓김치','볶은김치','볶음김치','석박지','단호박물김치', '수제보쌈김치','김치볶음','총각김치']
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], gimchi_list , '김치')
menu_data['H'].unique()
# Out:
# array([nan, '김치', '애호박나물', '쑥갓두부무침', '매운감자조림', '콩나물간장조림', '견과류샐러드',
#        '양상추샐러드'], dtype=object)

# %%
# 음료 데이터 분류
drink_list = ['우유', '두유', '주스', '아메리카노', '요구르트', '요플레', '식혜', '짜요짜요',
              '피크닉', '쥬스', '두유', '프로바이오틱', '아이스티', '요거트', '에이드', '드링킹', '음료', '쥬시쿨', '수제생강대추차']
for x in menu_data.columns: # 열별로 처리
    categorize(menu_data[x], drink_list, '음료')
menu_data.head(3)
# Out:
#    A   B      C         D  E        F   G    H    I
# 0  빵  음료  계란후라이    호두죽/쌀밥  국    쥐어채무침  김치  NaN  NaN
# 1  빵  음료  계란후라이     팥죽/쌀밥  국    시래기조림  김치  NaN  NaN
# 2  빵  음료  계란후라이  표고버섯죽/쌀밥  국  느타리호박볶음  김치  NaN  NaN

# %%
# 계란
egg_list = ['찐계란', '계란후라이', '스크램블에그', '스크램블', '구운계란', 
            '삶은계란', '계란말이', '계란찜'] 
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], egg_list, '계란')
menu_data.head(3)
# Out:
#    A   B   C         D  E        F   G    H    I
# 0  빵  음료  계란    호두죽/쌀밥  국    쥐어채무침  김치  NaN  NaN
# 1  빵  음료  계란     팥죽/쌀밥  국    시래기조림  김치  NaN  NaN
# 2  빵  음료  계란  표고버섯죽/쌀밥  국  느타리호박볶음  김치  NaN  NaN

# %%
# 면
noodle_list = ['스파게티', '쫄면', '짬뽕', '냉면', '라면', '짜장면', '우동', '소바', 
             '파스타', '잡채', '메밀면', '나가사키면', '알리오올리오']
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], noodle_list , '면')
menu_data.head(3)
# Out:
#    A   B   C         D  E        F   G    H    I
# 0  빵  음료  계란    호두죽/쌀밥  국    쥐어채무침  김치  NaN  NaN
# 1  빵  음료  계란     팥죽/쌀밥  국    시래기조림  김치  NaN  NaN
# 2  빵  음료  계란  표고버섯죽/쌀밥  국  느타리호박볶음  김치  NaN  NaN

# %%
# 과일
fruit_list = ['사과', '오렌지', '귤', '수박', '토마토', '과일', '참외', '포도', 
              '배', '청포도', '바나나']
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], fruit_list , '과일')
menu_data.head(3)
# Out:
#    A   B   C  D  E        F   G    H    I
# 0  빵  음료  계란  밥  국    쥐어채무침  김치  NaN  NaN
# 1  빵  음료  계란  밥  국    시래기조림  김치  NaN  NaN
# 2  빵  음료  계란  밥  국  느타리호박볶음  김치  NaN  NaN

# %%
# 오리고기
duck_list = ['오리']
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], duck_list , '오리')
menu_data.head(3)
# Out:
#    A   B   C         D  E        F   G    H    I
# 0  빵  음료  계란    호두죽/쌀밥  국    쥐어채무침  김치  NaN  NaN
# 1  빵  음료  계란     팥죽/쌀밥  국    시래기조림  김치  NaN  NaN
# 2  빵  음료  계란  표고버섯죽/쌀밥  국  느타리호박볶음  김치  NaN  NaN

# %%
# 소고기
beef_list = ['소고기','육전','떡갈비','쇠불고기', '쇠고기', '갈비탕', '소불고기','너비아니'
, '소갈비', '스테이크', 'LA갈비', '차돌박이', '우불고기']
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], beef_list , '소고기')
menu_data['E'].unique()
# Out:
# array(['국', '버섯죽/쌀밥', '<120명', '흑임자죽/쌀밥', '과일', '비타민샐러드', '양상추샐러드',
#        '베이비샐러드', '청포묵무침', '마늘쫑무침', '견과류조림', '시금치나물', '청경채무침', '쌈무/양파절임',
#        '유채나물', '콩나물무침', '취나물', '치커리무침', '음료', '돌나물무침/치킨무', '파래김', '꽃상추무침',
#        '곰피초장', '도라지초무침', '치커리생채', '아삭고추무침', '무생채', '열무된장나물', '톳두부무침',
#        '풋마늘초무침', '면', '콩나물파채무침', '마늘쫑볶음', '무나물', '깻순나물', '쌈무/부추생채',
#        '도토리묵무침', '실곤약초무침', '시래기나물', '열무나물', '치커리유자청생채', '봄동나물', '모둠쌈',
#        '브로컬리두부무침', '해초무침', '부추생채', '청경채생채', '깻잎양념지', '버섯볶음', '풋마늘대무침',
#        '콩자반/치킨무', '비름나물', '가지나물', '통도라지구이', '치커리유자생채', '숙주나물', '불미나리무침',
#        '오이무침', '고구마순나물', '오이도라지생채', '머위대나물', '브로컬리초장', '어묵볶음', '김구이',
#        '오이무침/치킨무', '간장깻잎지', '쌈무/야채스틱', '김치', '노각무침', '오이생채', '영양부추',
#        '모듬쌈', '도라지나물', '치커리들깨무침', '깻잎지', '쌈무/참나물생채', '연근조림', '콩자반',
#        '꽈리고추찜', '시금치무침', '상추&마늘', '쑥갓두부무침', '치커리유자청무침', '올방개묵무침', '오리',
#        '호박잎쌈', '연두부', '참나물땅콩무침', '애호박나물', '참나물생채', '마늘쫑건새우볶음', '동태/새송이전',
# ...

# %% [markdown]
# ## 밥/죽 데이터

# %%
# 밥, 죽
rice_list = ['밥','죽', '라이스', '필라프', '빠에야', '팟시금치무쌉', '프리타타', '호박숙']
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], rice_list , '밥')
menu_data.head(3)
# Out:
#    A   B   C  D  E        F   G    H    I
# 0  빵  음료  계란  밥  국    쥐어채무침  김치  NaN  NaN
# 1  빵  음료  계란  밥  국    시래기조림  김치  NaN  NaN
# 2  빵  음료  계란  밥  국  느타리호박볶음  김치  NaN  NaN

# %% [markdown]
# ## 닭고기 데이터

# %%
menu_data['C'].unique()
# Out:
# array(['계란', '밥', '음료', '소고기', '가자미튀김', '치킨핑거', '주꾸미볶음', '돼지고기', '오리',
#        '닭감자조림', '국', '고구마치즈구이', '마늘간장치킨', '갈치구이', '닭갈비', '오징어볶음',
#        '고등어김치말이', '닭데리야끼조림', '버섯불고기', '코다리강정', '치킨텐더', '자반고등어구이', '오징어튀김',
#        '갈치조림', '순살양념치킨', '꽁치한마리구이', '궁중떡찜', '양념파닭', '모둠장조림', '찜닭',
#        '닭오븐구이', '꼬지삼색전', '닭양념조림', '순살깐풍기', '가자미양념찜', '간장치킨', '매콤낙지볶음',
#        '고등어구이', '꽁치김치말이찜', '닭강정', '순살파닭', '매운주꾸미볶음', '고추장불고기', '불닭볶음',
#        '꽁치오븐구이', '꽃맛살볶음', '미니함박조림', '장어강정', '새우까스&탈탈소스', '고등어조림', '면',
#        '닭볶음', '동태무조림', '마늘치킨', '닭찜', '가자미카레튀김', '유린기', '임연수찜', '간장파닭',
#        '생선커틀릿', '꽁치김치말이', '데리야끼파닭', '쭈꾸미볶음', '명태엿장조림', '유산슬', '해물김치전',
#        '파닭', '통감자오븐구이', '양념찜닭', '삼치무조림', '고구마튀김', '매운동태찜', '동그랑땡전',
#        '굴비구이', '주꾸미떡볶음', '생선까스', '매운닭찜', '언양식불고기', '낙지볶음', '깐풍기', '팝콘치킨',
#        '순살닭갈비', '해물청경채볶음', '치킨커틀렛', '콩나물불고기', '생선커틀렛', '간장찜닭', '삼치된장구이',
#        '삼치구이', '오징어굴소스볶음', '해물까스', '주꾸미굴소스볶음', '단호박장조림', '꽁치구이', '개성감자만두',
# ...

# %% [markdown]
# 닭개장, 닭곰탕, 백숙, 삼계탕 ==> 찌개, 국??
#
# 닭칼국수
# 치킨샐러드??

# %%
# 닭고기
chicken_list = ['닭', '치킨', '교촌윙', '강정', '깐풍기', '유린기', '후라이드', 
                '궁보계정', '장각', '삼계탕', '코코뱅']
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], chicken_list , '닭고기')
menu_data.head(3)
# Out:
#    A   B   C  D  E        F   G    H    I
# 0  빵  음료  계란  밥  국    쥐어채무침  김치  NaN  NaN
# 1  빵  음료  계란  밥  국    시래기조림  김치  NaN  NaN
# 2  빵  음료  계란  밥  국  느타리호박볶음  김치  NaN  NaN

# %% [markdown]
# ## 생선류 데이터

# %%
menu_data['C'].unique()
# Out:
# array(['계란', '밥', '음료', '소고기', '가자미튀김', '닭고기', '주꾸미볶음', '돼지고기', '오리', '국',
#        '고구마치즈구이', '갈치구이', '오징어볶음', '고등어김치말이', '버섯불고기', '자반고등어구이', '오징어튀김',
#        '갈치조림', '꽁치한마리구이', '궁중떡찜', '모둠장조림', '꼬지삼색전', '가자미양념찜', '매콤낙지볶음',
#        '고등어구이', '꽁치김치말이찜', '매운주꾸미볶음', '고추장불고기', '꽁치오븐구이', '꽃맛살볶음',
#        '미니함박조림', '새우까스&탈탈소스', '고등어조림', '면', '동태무조림', '가자미카레튀김', '임연수찜',
#        '생선커틀릿', '꽁치김치말이', '쭈꾸미볶음', '명태엿장조림', '유산슬', '해물김치전', '통감자오븐구이',
#        '삼치무조림', '고구마튀김', '매운동태찜', '동그랑땡전', '굴비구이', '주꾸미떡볶음', '생선까스',
#        '언양식불고기', '낙지볶음', '해물청경채볶음', '콩나물불고기', '생선커틀렛', '삼치된장구이', '삼치구이',
#        '오징어굴소스볶음', '해물까스', '주꾸미굴소스볶음', '단호박장조림', '꽁치구이', '개성감자만두',
#        '코다리조림', '생선까스&탈탈소스', '명태코다리조림', '매콤미니함박', '조기구이', '류산슬',
#        '코다리양념조림', '완자전', '삼치데리야끼', '생야채', '삼치양념구이', '갈치양념조림', '동태포전',
#        '꽁치레몬구이', '모듬장조림', '김치전', '생선가스', '새우까스', '메추리알조림', '야채튀김', '순대볶음',
#        '부추전', '갈비통통만두', '해물굴소스볶음', '딸기드레싱샐러드', '감자치즈구이', '모듬튀김', '또띠아피자',
# ...

# %% [markdown]
# 대구매운탕, 알탕?, 동태탕, 동태매운탕, 아귀매운탕 ==> 탕?

# %% [markdown]
# '가자미튀김', '갈치구이', '고등어김치말이', '코다리강정', '자반고등어구이', '갈치조림', '꽁치한마리구이', '가자미양념찜', '고등어구이', '꽁치김치말이찜', '꽁치오븐구이',
# '장어강정', '고등어조림', '동태무조림', '가자미카레튀김', '임연수찜', '생선커틀릿', '꽁치김치말이', '명태코다리', '생선까스...', '방어양념장구이'
#
# '적어구이'

# %%
fish_list = ['가자미', '갈치', '고등어', '코다리', '꽁치', '장어', '임연수', '삼치', '굴비',
             '황태', '동태', '명태', '열기어', '적어', '방어', '연여', '조기', '생선', '고갈비', '아귀', '탕수어', '참치', '연어', '대구', '노가리', '홍어', '꽁채캔김치조림']
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], fish_list , '생선류')
menu_data.head(3)
# Out:
#    A   B   C  D  E        F   G    H    I
# 0  빵  음료  계란  밥  국    쥐어채무침  김치  NaN  NaN
# 1  빵  음료  계란  밥  국    시래기조림  김치  NaN  NaN
# 2  빵  음료  계란  밥  국  느타리호박볶음  김치  NaN  NaN

# %% [markdown]
# ## 샐러드 데이터

# %%
# 샐러드
salad_list = ['샐러드']
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], salad_list , '샐러드')
menu_data.head(3)
# Out:
#    A   B   C  D  E        F   G    H    I
# 0  빵  음료  계란  밥  국    쥐어채무침  김치  NaN  NaN
# 1  빵  음료  계란  밥  국    시래기조림  김치  NaN  NaN
# 2  빵  음료  계란  밥  국  느타리호박볶음  김치  NaN  NaN

# %% [markdown]
# ## 7/15 특별메뉴

# %%
menu_data['A'].unique()

# 마파두부
# Out:
# array(['빵', '밥', '소고기', '<초복특식>', '돼지고기', '국', '김치', '면', '0', '오리',
#        '특별메뉴'], dtype=object)

# %%
menu_data['B'].unique()

# 인도커리&난
# Out:
# array(['음료', '국', '빵', '돼지고기', '밥', '면', nan, '특별메뉴', '닭고기', '소고기',
#        '오복지무침', '백종원의', '김치', '계란'], dtype=object)

# %%
menu_data['C'].unique()

# 주꾸미, 오징어, 새우, 유산슬, 쭈꾸미, 류산슬, 순대, 또띠아피자
# 튀김, 해물까스, 핫도그, 떡볶이, 순대, 피자, 라볶이, 소떡소떡, 통감자오븐구이, 양장피, 허니버터옥수수, 멘보샤, 퀘사디아, 만두, 딤섬, 춘권, 고로케

# 소고기 - 매운사태조림
# 반찬인가? 만두(딤섬), 전
# Out:
# array(['계란', '밥', '음료', '소고기', '특별메뉴', '닭고기', '돼지고기', '오리', '국',
#        '고구마치즈구이', '버섯불고기', '모둠장조림', '꼬지삼색전', '고추장불고기', '꽃맛살볶음', '미니함박조림',
#        '면', '동그랑땡전', '언양식불고기', '콩나물불고기', '단호박장조림', '매콤미니함박', '완자전', '생야채',
#        '모듬장조림', '김치전', '메추리알조림', '부추전', '샐러드', '감자치즈구이', nan, '우엉불고기',
#        '수원왕갈비', '깻잎전', '바싹불고기', '오삼불고기', '부추고추전', '만가닥버섯불고기', '쭈삼불고기',
#        '대패삽겹숙주볶음', '짜장소스', '콩나물파채불고기', '메밀전병', '미니함박', '빵', '감자버터구이',
#        '과일', '궁중떡볶음', '단호박조림', '웨지감자', '고구마오븐구이', '감자치즈오븐구이', '양념갈비찜',
#        '두부커틀릿', '김치', '간장불고기', '더덕고추장불고기', '고추짜장', '고구마까스', '쌈추전',
#        '매운사태찜', '섭산적고추장구이', '숯불양념꼬치어묵', '언양식바싹불고기', '가래떡오븐구이', '자장소스',
#        '브로콜리깨소스무침', '매운사태조림'], dtype=object)

# %%
menu_data['D'].unique()

# '양상추,'?, 타코야끼, '골뱅이'
# Out:
# array(['밥', '소고기', '계란', '국', '샐러드', '돼지고기', '면', '부추전', '도토리묵무침', '옥수수전',
#        '연두부', '특별메뉴', '통도라지구이', '해초무침', '새송이버섯볶음', '호박꼬지&고사리&무나물',
#        '새싹두부구이', '늙은호박전', '새송이버섯조림', '메추리알조림', '모둠묵', '모둠양채쌈', '두부계란부침',
#        '파래김', '연근땅콩조림', '김치', '땅콩조림', '해파리냉채', '새송이버섯전', '알감자버터구이',
#        '브로컬리맛살볶음', '두부조림', '무쌈/양파절임', '열무나물', '과일', '도라지초무침', '고기전',
#        '청포묵무침', '연근조림', '김치전', '동그랑땡부침', '맛살겨자채', '온두부', '멸치크랜베리볶음',
#        '꽃맛살볶음', '우엉조림', '동그랑땡전', '두부구이', '맛살콩나물냉채', '마늘쫑볶음', '실곤약초무침',
#        '닭고기', '두부새싹구이', '맛살겨자초무침', '감자볶음', '해파리겨자채', '감자채볶음', '마늘쫑무침',
#        '웨지감자오븐구이', '매운어묵볶음', '고구마범벅', '모둠버섯볶음', '동그랑땡', '어묵볶음', '호박부추전',
#        '가지볶음', '메추리알곤약조림', nan, '모듬묵', '계란버섯장조림', '셀프무쌈말이', '메밀버섯전',
#        '두부계란전', '양파절임', '올방개묵무침', '콩나물겨자채', '실곤약흑임자무침', '버섯메밀전', '매운어묵무침',
#        '비엔케찹볶음', '꽈리고추어묵볶음', '부추깻잎전', '언양식불고기', '두반장감자볶음', '무쌈말이',
#        '모듬버섯구이', '삼색묵무침', '삼색꼬지전', '연두부찜', '감자전', '땅콩멸치볶음', '녹두김치전',
# ...

# %%
menu_data['E'].unique()
# Out:
# array(['국', '밥', '<120명', '과일', '샐러드', '청포묵무침', '마늘쫑무침', '견과류조림', '시금치나물',
#        '청경채무침', '쌈무/양파절임', '유채나물', '콩나물무침', '취나물', '치커리무침', '음료', '닭고기',
#        '파래김', '꽃상추무침', '곰피초장', '도라지초무침', '치커리생채', '아삭고추무침', '무생채',
#        '열무된장나물', '톳두부무침', '풋마늘초무침', '면', '콩나물파채무침', '마늘쫑볶음', '무나물',
#        '깻순나물', '쌈무/부추생채', '도토리묵무침', '실곤약초무침', '시래기나물', '열무나물', '치커리유자청생채',
#        '봄동나물', '모둠쌈', '브로컬리두부무침', '해초무침', '부추생채', '청경채생채', '깻잎양념지',
#        '버섯볶음', '풋마늘대무침', '비름나물', '가지나물', '통도라지구이', '치커리유자생채', '숙주나물',
#        '불미나리무침', '오이무침', '고구마순나물', '오이도라지생채', '머위대나물', '브로컬리초장', '어묵볶음',
#        '김구이', '간장깻잎지', '쌈무/야채스틱', '김치', '노각무침', '오이생채', '영양부추', '모듬쌈',
#        '도라지나물', '치커리들깨무침', '깻잎지', '쌈무/참나물생채', '연근조림', '콩자반', '꽈리고추찜',
#        '시금치무침', '상추&마늘', '쑥갓두부무침', '치커리유자청무침', '올방개묵무침', '오리', '호박잎쌈',
#        '연두부', '참나물땅콩무침', '애호박나물', '참나물생채', '특별메뉴', '참나물무침', '오복지무침',
#        '매운어묵볶음', '멸치크렌베리볶음', '미역레몬초무침', '땅콩조림', '세발나물', '상추파채무침',
# ...

# %%
menu_data['F'].unique()
# Out:
# array(['쥐어채무침', '시래기조림', '느타리호박볶음', '멸치볶음', '방풍나물', '명엽채무침', '숙주나물',
#        '콩조림', '김구이', '무생채', '톳두부무침', '오이생채', '시금치나물', '참나물땅콩가루무침',
#        '애호박나물', '어묵볶음', '곰피초장', '오이무침', '가지볶음', '볼어묵볶음', '쑥갓무침', '유채나물',
#        '김자반', '검정콩조림', '미역줄기볶음', '브로컬리들깨찜', '김실파무침', '브로컬리초장', '쑥갓두부무침',
#        '크랜베리멸치볶음', '진미채무침', '미역레몬초무침', '참나물무침', '마늘쫑무침', '구이김', '감자채볶음',
#        '콩나물무침', '곤약어묵볶음', '느타리볶음', '비름나물', '열무나물', '마늘쫑볶음', '오이도라지무침',
#        '호박나물', '취나물', '노각무침', '머위대나물', '멸치캐슈넛볶음', '가지나물', '사각어묵무침',
#        '멸치고추장무침', '새송이버섯볶음', '고구마순나물', '볼어묵조림', '두부조림', '멸치호두볶음',
#        '숙주미나리나물', '콩자반', '버섯볶음', '시래기나물', '사각어묵볶음', '새송이볶음', '아삭고추무침',
#        '호박볶음', '참나물땅콩무침', '도라지나물', '꽈리고추찜', '애호박볶음', '김잔파무침', '감자조림',
#        '김가루실파무침', '브로컬리들깨무침', '치커리무침', '구구마순나물', '미역나물', '연근조림',
#        '마늘쫑맛살볶음', '쥐포무침', '청포묵무침', '가지두반장볶음', '우엉조림', '느타리버섯볶음', '꽃맛살볶음',
#        '미니새송이볶음', '톳무침', '겨울초나물', '무채나물', '브로컬리무침', '크래미숙주무침', '김치',
# ...

# %%
menu_data['G'].unique()
# Out:
# array(['김치', '밥', '국', '과일', '돼지고기', '브로콜리감자볶음', '미나리숙주무침', '고사리들깨나물',
#        '들기름무채볶음', '두부계란전', '시금치두부무침', '치커리오이무침', '샐러드', '마늘쫑메추리알장조림',
#        '명엽체고추장볶음', '시금치나물무침', '알감자조림', '병아리', nan, '음료', '이벤트행사', '닭고기',
#        '면', '빵'], dtype=object)

# %%
menu_data['H'].unique()
# Out:
# array([nan, '김치', '애호박나물', '쑥갓두부무침', '매운감자조림', '콩나물간장조림', '샐러드'],
#       dtype=object)

# %%
menu_data['I'].unique()
# Out:
# array([nan, '김치'], dtype=object)

# %%
# 특별메뉴
special_list = ['마파두부', '인도커리', '주꾸미', '오징어', '새우', '유산슬', '쭈꾸미', '류산슬', '순대', '피자', '튀김', 
                '핫도그', '떡볶이', '순대', '라볶이', '소떡소떡', '통감자오븐구이', '양장피', '허니버터옥수수', '멘보샤', '퀘사디아', '해물', 
                '궁중떡찜', '낙지', '문어', '만두', '딤섬', '춘권', '고로케', '타코야끼', '타꼬야끼', '골뱅이', '칠리베이비크랩', '가래떡츄러스', '푸딩',
                '햄버거', '찜']
for x in menu_data.columns: # 열별로 처리 
    categorize(menu_data[x], special_list , '특별메뉴')
menu_data.head(3)
# Out:
#    A   B   C  D  E        F   G    H    I
# 0  빵  음료  계란  밥  국    쥐어채무침  김치  NaN  NaN
# 1  빵  음료  계란  밥  국    시래기조림  김치  NaN  NaN
# 2  빵  음료  계란  밥  국  느타리호박볶음  김치  NaN  NaN
